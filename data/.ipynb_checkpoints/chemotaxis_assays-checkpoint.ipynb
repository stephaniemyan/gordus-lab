# %% [markdown]
# # Data analysis of chemotaxis assays
# ### Author: Stephanie M. Yan
# ### April 23, 2019
#
# Worms are trained for either 8 hrs or 24 hrs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats

# %%
# read in file with data
df8 = pd.read_csv("/Users/cmdb/Documents/gordus-lab/data/8hr_chemotaxis.csv", sep=",", index_col=0)
df8 = -df8
df8
# Out:
#         naive_choice_index  trained_choice_index  P0_learning_index  \
# date
# 10-Apr           -0.270833              0.466667          -0.737500
# 12-Apr           -0.183673              0.373494          -0.557167
# 15-Apr           -0.306667             -0.194969          -0.111698
# 16-Apr           -0.423313              0.523810          -0.947122
# 19-Apr           -0.760000             -0.604938          -0.155062
# 20-Apr           -0.549669              0.098592          -0.648260
# 21-Apr           -0.136842              0.365854          -0.502696
# 22-Apr           -0.727660             -0.184211          -0.543449
# 23-Apr           -0.606742              0.925373          -1.532115
# 24-Apr           -0.380117             -0.021834          -0.358283
# 25-Apr           -0.376471              0.341463          -0.717934
#
#         F1_naive_choice_index  F1_trained_choice_index  F1_learning_index  \
# date
# 10-Apr                    NaN                      NaN                NaN
# 12-Apr               0.087379                 0.068702           0.018676
# 15-Apr                    NaN                      NaN                NaN
# 16-Apr              -0.009901                 0.422222          -0.432123
# 19-Apr                    NaN                      NaN                NaN
# 20-Apr              -0.446809                -0.714286           0.267477
# 21-Apr              -0.500000                -0.212121          -0.287879
# 22-Apr               0.127273                 0.011673           0.115600
# 23-Apr               0.154286                -0.021277           0.175562
# 24-Apr               0.076923                 0.170732          -0.093809
# 25-Apr              -0.052632                 0.270718          -0.323350
#
#           F1_PLI  F2_naive_choice_index  F2_trained_choice_index  \
# date
# 10-Apr       NaN                    NaN                      NaN
# 12-Apr  0.575844                    NaN                      NaN
# 15-Apr       NaN                    NaN                      NaN
# 16-Apr  0.514999                    NaN                      NaN
# 19-Apr       NaN                    NaN                      NaN
# 20-Apr  0.915738                    NaN                      NaN
# 21-Apr  0.214817               0.007752                 0.007752
# 22-Apr  0.659049               0.005464                 0.183099
# 23-Apr  1.707677              -1.000000                 0.106719
# 24-Apr  0.264474               0.300000                 0.216667
# 25-Apr  0.394584                    NaN                      NaN
#
#         F2_learning_index    F2_PLI
# date
# 10-Apr                NaN       NaN
# 12-Apr                NaN       NaN
# 15-Apr                NaN       NaN
# 16-Apr                NaN       NaN
# 19-Apr                NaN       NaN
# 20-Apr                NaN       NaN
# 21-Apr          -0.266973  0.235722
# 22-Apr          -0.177634  0.365815
# 23-Apr          -1.106719  0.425395
# 24-Apr           0.083333  0.441616
# 25-Apr                NaN       NaN

# %%
df24 = pd.read_csv("/Users/cmdb/Documents/gordus-lab/data/24hr_chemotaxis.csv", sep=",", index_col=0)
df24 = -df24
df24
# Out:
#         naive_choice_index  trained_choice_index  P0_learning_index  \
# date
# 28-Apr            0.160714              0.239437          -0.078722
# 29-Apr           -0.953488              0.232323          -1.185812
# 1-May            -0.958333             -0.134146          -0.824187
# 2-May            -0.608696              0.428571          -1.037267
# 4-May            -0.073684              0.032258          -0.105942
# 6-May            -0.909091              0.730769          -1.639860
# 7-May            -0.095238              0.441696          -0.536934
# 8-May            -0.220779              0.732558          -0.953337
# 9-May             0.103448              0.346614          -0.243165
# 10-May           -0.410853              0.740385          -1.151237
# 14-May           -0.553571              0.206612          -0.760183
#
#         F1_naive_choice_index  F1_trained_choice_index  F1_learning_index  \
# date
# 28-Apr               0.216080                -0.226994           0.443074
# 29-Apr               0.056180                 0.333333          -0.277154
# 1-May                0.024793                 0.182796          -0.158002
# 2-May               -0.078652                -0.344262           0.265611
# 4-May                0.013333                 0.117904          -0.104571
# 6-May                0.159763                 0.331058          -0.171295
# 7-May               -0.152542                 0.030675          -0.183217
# 8-May                0.094077                 0.267857          -0.173780
# 9-May               -0.253731                -0.336449           0.082717
# 10-May              -0.185484                -0.123810          -0.061674
# 14-May               0.196172                 0.153333           0.042839
#
#           F1_PLI  F2_naive_choice_index  F2_trained_choice_index  \
# date
# 28-Apr  0.521797               0.012658                 0.056604
# 29-Apr  0.908658              -1.000000                 0.438849
# 1-May   0.666185              -0.000000                -0.333333
# 2-May   1.302878               0.029940                -0.057627
# 4-May   0.001372              -0.333333                 0.180556
# 6-May   1.468565               0.512195                 0.500000
# 7-May   0.353717                    NaN                      NaN
# 8-May   0.779557                    NaN                      NaN
# 9-May   0.325883                    NaN                      NaN
# 10-May  1.089563                    NaN                      NaN
# 14-May  0.803022                    NaN                      NaN
#
#         F2_learning_index    F2_PLI
# date
# 28-Apr          -0.043946  0.034777
# 29-Apr          -1.438849 -0.253037
# 1-May            0.333333  1.157520
# 2-May            0.087567  1.124834
# 4-May           -0.513889 -0.407947
# 6-May            0.012195  1.652055
# 7-May                 NaN       NaN
# 8-May                 NaN       NaN
# 9-May                 NaN       NaN
# 10-May                NaN       NaN
# 14-May                NaN       NaN

# %%
# colors = ["gold", "lightskyblue", "darkgoldenrod", "dodgerblue", "saddlebrown", "navy"]
colors = ["gold", "dodgerblue", "gold", "dodgerblue", "gold", "dodgerblue"]
sns.set_palette(colors)

labels = ["Parental (naive)", "Parental (trained)", "F1 (naive)", "F1 (trained)", "F2 (naive)", "F2 (trained)"]

def plot_boxplots(dataframe, time):
    
    df_plot = pd.DataFrame({"generation":dataframe.index.tolist()})
    
    df_plot["p0_o_CIs"] = dataframe["naive_choice_index"].tolist()
    df_plot["p0_p_CIs"] = dataframe["trained_choice_index"].tolist()
    df_plot["f1_o_CIs"] = dataframe["F1_naive_choice_index"].tolist()
    df_plot["f1_p_CIs"] = dataframe["F1_trained_choice_index"].tolist()
    df_plot["f2_o_CIs"] = dataframe["F2_naive_choice_index"].tolist()
    df_plot["f2_p_CIs"] = dataframe["F2_trained_choice_index"].tolist()
   
    df_plot.set_index("generation", inplace=True)
    
    # I checked, they're all normally distributed
#     print(scipy.stats.shapiro(df_plot['p0_o_CIs'].dropna()))
#     print(scipy.stats.shapiro(df_plot['p0_p_CIs'].dropna()))
#     print(scipy.stats.shapiro(df_plot['f1_o_CIs'].dropna()))
#     print(scipy.stats.shapiro(df_plot['f1_p_CIs'].dropna()))
#     print(scipy.stats.shapiro(df_plot['f2_o_CIs'].dropna()))
#     print(scipy.stats.shapiro(df_plot['f2_p_CIs'].dropna()))

    print(scipy.stats.ttest_ind(df_plot['p0_o_CIs'].dropna(),df_plot['p0_p_CIs'].dropna()))
    print(scipy.stats.ttest_ind(df_plot['f1_o_CIs'].dropna(),df_plot['f1_p_CIs'].dropna()))
    print(scipy.stats.ttest_ind(df_plot['f2_o_CIs'].dropna(),df_plot['f2_p_CIs'].dropna()))
    
    x1, x2 = 0, 1
    x3, x4 = 2, 3
    x5, x6 = 4, 5 # columns 'Sat' and 'Sun' (first column: 0, see plt.xticks())
    # y, h, col = df_plot["p0_o_CIs"].max() + 0.2, 0.2, 'k'
    
    fig, ax = plt.subplots(figsize=(15,7.5))
    sns.boxplot(data = df_plot)
    sns.swarmplot(data = df_plot, color = ".2")
    ax.set_title("Food choice after " + time + " training", fontsize=20)
    ax.set_ylabel("Food choice", fontsize=20)
    ax.set_xticklabels(labels, fontsize=15)
    ax.set_ylim([-1,1.25])
    plt.plot([x1, x1, x2, x2], [1.01, 1.1, 1.1, 1.01], lw=1, c='k')
    plt.plot([x3, x3, x4, x4], [1.01, 1.1, 1.1, 1.01], lw=1, c='k')
    plt.plot([x5, x5, x6, x6], [1.01, 1.1, 1.1, 1.01], lw=1, c='k')

    plt.text((x1+x2)*.5, 1.13, "***", ha='center', va='bottom', color='k')
    plt.text((x3+x4)*.5, 1.13, "n.s.", ha='center', va='bottom', color='k')
    plt.text((x5+x6)*.5, 1.13, "n.s.", ha='center', va='bottom', color='k')
    fig.savefig("/Users/cmdb/Documents/gordus-lab/data/" + time + ".png", transparent=True)

# %%
plot_boxplots(df8, "8hr")
# Out:
# Ttest_indResult(statistic=-4.353511112350255, pvalue=0.00030787814520575186)
# Ttest_indResult(statistic=-0.4579693362361378, pvalue=0.6540019471600533)
# Ttest_indResult(statistic=-1.0411656096949398, pvalue=0.3379226668228769)

# %%
plot_boxplots(df24, "24hr")
# Out:
# Ttest_indResult(statistic=-5.054589309244447, pvalue=6.063279878641637e-05)
# Ttest_indResult(statistic=-0.2968928697889132, pvalue=0.7696097388753288)
# Ttest_indResult(statistic=-1.074810018830949, pvalue=0.3077086176092365)
